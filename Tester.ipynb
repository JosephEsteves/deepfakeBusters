# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras import optimizers
import matplotlib.pyplot as plt
import numpy as np
#import cv2
import os
import tensorflow as tf
# Out:
# 2024-11-08 11:54:02.662079: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-08 11:54:02.662154: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-08 11:54:02.667800: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-08 11:54:02.684152: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
test = ImageDataGenerator(rescale = 1/255)

# %%
full_test = tf.keras.preprocessing.image_dataset_from_directory("EEdataset1/Dataset/Test")
# Out:
# Found 10905 files belonging to 2 classes.
# 2024-11-08 11:54:09.108261: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
ds_test = full_test

# %%
# define the batch size and print the image labels
#import tensorflow_datasets as tfds

batch_size = 64 # Dividing the subsets of the data into smaller chunks that our model can be able to understand.

dataset_name = ds_test
class_names = full_test.class_names
print(class_names) #Display the names of the subfolder that are in the main folder.
# Out:
# ['Fake', 'Real']

# %%
#resize your images and standardize your data to make it for a neural network
#Standardize your data
size = (90,90)
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

# %%
NUM_CLASSES = len(class_names)

# %%
len(class_names)
# Out:
# 2

# %%
#One_hot / categorical encoding
def input_preprocess(image, label):
  label = tf.one_hot(label, NUM_CLASSES)
  return image, label

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 31ms/step - loss: 0.3460 - accuracy: 0.8813 - recall: 0.8813 - precision: 0.8813
# Test accuracy : 0.8813388347625732
# recall : 0.8813388347625732

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best1.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 29ms/step - loss: 0.2652 - accuracy: 0.9044 - recall: 0.9044 - precision: 0.9044
# Test accuracy : 0.9044474959373474
# recall : 0.9044474959373474

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best2.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 10s 28ms/step - loss: 0.2980 - accuracy: 0.8909 - recall: 0.8909 - precision: 0.8909
# Test accuracy : 0.8908757567405701
# recall : 0.8908757567405701

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best3.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 10s 29ms/step - loss: 0.2355 - accuracy: 0.9107 - recall: 0.9107 - precision: 0.9107
# Test accuracy : 0.9106831550598145
# recall : 0.9106831550598145

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best4.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 29ms/step - loss: 0.3145 - accuracy: 0.8921 - recall: 0.8921 - precision: 0.8921
# Test accuracy : 0.8920678496360779
# recall : 0.8920678496360779

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best5.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 10s 29ms/step - loss: 0.3120 - accuracy: 0.8954 - recall: 0.8954 - precision: 0.8954
# Test accuracy : 0.8953691124916077
# recall : 0.8953691124916077

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best6.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 29ms/step - loss: 0.3285 - accuracy: 0.8963 - recall: 0.8963 - precision: 0.8963
# Test accuracy : 0.896286129951477
# recall : 0.896286129951477

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best7.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 29ms/step - loss: 0.4741 - accuracy: 0.8753 - recall: 0.8753 - precision: 0.8753
# Test accuracy : 0.8752865791320801
# recall : 0.8752865791320801

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Best8.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 30ms/step - loss: 0.3406 - accuracy: 0.8965 - recall: 0.8965 - precision: 0.8965
# Test accuracy : 0.8964695334434509
# recall : 0.8964695334434509

# %%
from tensorflow.keras.models import load_model
#Note:'Keras/90x90Best1.keras' has the best performance so far. Epoch 36
# Load the model
model = load_model('Keras/90x90Epoch.keras')

# %%
test = ds_test
loss, accuracy, precision, recall = model.evaluate(test)
print('Test accuracy :', accuracy)
print('recall :', recall)
# Out:
# 341/341 [==============================] - 11s 30ms/step - loss: 0.4272 - accuracy: 0.8940 - recall: 0.8940 - precision: 0.8940
# Test accuracy : 0.8939935564994812
# recall : 0.8939935564994812
